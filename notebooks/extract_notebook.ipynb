# %%
import pandas as pd
import csv
import logging
import sys
sys.path.append('../')

# %%
logger = logging.getLogger()
formatter= logging.Formatter('%(asctime)s -%(lineno)s -%(levelname)s-%(message)s')
logger.setLevel(logging.DEBUG)
fhandler= logging.FileHandler(filename='../airflow-docker/logs/notebook.log', mode='w')
fhandler.setFormatter(formatter)
fhandler.setLevel(logging.INFO)
logger.addHandler(fhandler)

# %%
data= pd.read_csv('../data/20181024_d1_0830_0900.csv')

# %%
data.head()
# Out:
#   track_id; type; traveled_d; avg_speed; lat; lon; speed; lon_acc; lat_acc; time
# 0  1; Car; 48.85; 9.770344; 37.977391; 23.737688;...
# 1  2; Motorcycle; 98.09; 19.839417; 37.977642; 23...
# 2  3; Motorcycle; 63.80; 18.228752; 37.977997; 23...
# 3  4; Motorcycle; 145.72; 26.229014; 37.978135; 2...
# 4  5; Motorcycle; 138.01; 24.841425; 37.978134; 2...

# %%
track_ids = []
types = []
traveled_d = []
avg_speeds = []
trajectories = []

for r in range(len(data)): 
    row = data.iloc[r,:][0].split(";")
    row_p1 = row[:4]
    row_p2 = row[4:]
    trajectory = ','.join(row_p2)
    
    track_ids.append(row_p1[0])
    types.append(row_p1[1])
    traveled_d.append(row_p1[2])
    avg_speeds.append(row_p1[3])
    trajectories.append(trajectory[1:])

# %%
columns = data.columns[0].split(";")[:4]
columns.append("trajectory")
columns[1] = "types"
for i in range(len(columns)):
    columns[i] = columns[i].strip()
logging.info('Run successful')
# Out:
# INFO:root:Run successful
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Stella\miniconda3\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "C:\Users\Stella\miniconda3\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# KeyError: 'messages'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Stella\miniconda3\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "C:\Users\Stella\miniconda3\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "C:\Users\Stella\miniconda3\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "C:\Users\Stella\miniconda3\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\Stella\miniconda3\lib\logging\__init__.py", line 436, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'messages'
# Call stack:
#   File "C:\Users\Stella\miniconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Stella\miniconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Stella\miniconda3\lib\site-packages\traitlets\config\application.py", line 976, in launch_instance
#     app.start()
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "C:\Users\Stella\miniconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Stella\miniconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\Stella\miniconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\Stella\miniconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel\ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Stella\miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Stella\miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#   File "C:\Users\Stella\miniconda3\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Stella\miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Stella\miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Stella\miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Stella\AppData\Local\Temp\ipykernel_10748\1853232298.py", line 6, in <cell line: 6>
#     logging.info('Run successful')
# Message: 'Run successful'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Stella\miniconda3\lib\logging\__init__.py", line 434, in format
#     return self._format(record)
#   File "C:\Users\Stella\miniconda3\lib\logging\__init__.py", line 430, in _format
#     return self._fmt % record.__dict__
# KeyError: 'messages'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Stella\miniconda3\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "C:\Users\Stella\miniconda3\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "C:\Users\Stella\miniconda3\lib\logging\__init__.py", line 666, in format
#     s = self.formatMessage(record)
#   File "C:\Users\Stella\miniconda3\lib\logging\__init__.py", line 635, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\Stella\miniconda3\lib\logging\__init__.py", line 436, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'messages'
# Call stack:
#   File "C:\Users\Stella\miniconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Stella\miniconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Stella\miniconda3\lib\site-packages\traitlets\config\application.py", line 976, in launch_instance
#     app.start()
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "C:\Users\Stella\miniconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Stella\miniconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\Stella\miniconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\Stella\miniconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel\ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Stella\miniconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Stella\miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Stella\miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#   File "C:\Users\Stella\miniconda3\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Stella\miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Stella\miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Stella\miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Stella\AppData\Local\Temp\ipykernel_10748\1853232298.py", line 6, in <cell line: 6>
#     logging.info('Run successful')
# Message: 'Run successful'
# Arguments: ()

# %%
data_dict= {columns[0]:track_ids, columns[1]:types, columns[2]:traveled_d, columns[3]:avg_speeds,columns[4]:trajectory}

# %%
df= pd.DataFrame(data_dict)

# %%
df.head()
# Out:
#   track_id        types traveled_d   avg_speed  \
# 0        1          Car      48.85    9.770344
# 1        2   Motorcycle      98.09   19.839417
# 2        3   Motorcycle      63.80   18.228752
# 3        4   Motorcycle     145.72   26.229014
# 4        5   Motorcycle     138.01   24.841425
#
#                                           trajectory
# 0   37.978428, 23.735538, 24.1909, -0.0077, -0.06...
# 1   37.978428, 23.735538, 24.1909, -0.0077, -0.06...
# 2   37.978428, 23.735538, 24.1909, -0.0077, -0.06...
# 3   37.978428, 23.735538, 24.1909, -0.0077, -0.06...
# 4   37.978428, 23.735538, 24.1909, -0.0077, -0.06...

# %%
df.to_csv('data_22_7_2022.csv')
