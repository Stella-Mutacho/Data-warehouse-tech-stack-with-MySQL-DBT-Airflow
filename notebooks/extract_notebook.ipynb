# %%
import pandas as pd
import csv

# %%
data= pd.read_csv('20181024_d1_0830_0900.csv', nrows=20, sep=';',header=None)

# %%
data.head()
# Out:
#           0      1            2           3     4     5       6         7  \
# 0  track_id   type   traveled_d   avg_speed   lat   lon   speed   lon_acc
#
#           8      9
# 0   lat_acc   time

# %%
with open('20181024_d1_0830_0900.csv') as file_obj:
    heading =next(file_obj)
    reader_obj= csv.reader(file_obj)
    for row in reader_obj:
        my_list=row[0].split(';')
        track_id= my_list[0]
        car_type=my_list[1]
        travelled_d= my_list[2]
        avg_speed=my_list[3]
        paths=my_list[4:]
        print(paths)
# Out:
# [' 37.977391', ' 23.737688', ' 4.9178', ' 0.0518', ' -0.0299', ' 0.000000', ' 37.977391', ' 23.737688', ' 4.9207', ' -0.0124', ' -0.0354', ' 0.040000', ' 37.977391', ' 23.737688', ' 4.9160', ' -0.0519', ' -0.0413', ' 0.080000', ' 37.977390', ' 23.737688', ' 4.9057', ' -0.0914', ' -0.0478', ' 0.120000', ' 37.977390', ' 23.737689', ' 4.8871', ' -0.1679', ' -0.0550', ' 0.160000', ' 37.977389', ' 23.737689', ' 4.8547', ' -0.2815', ' -0.0628', ' 0.200000', ' 37.977389', ' 23.737689', ' 4.8033', ' -0.4320', ' -0.0713', ' 0.240000', ' 37.977388', ' 23.737690', ' 4.7318', ' -0.5617', ' -0.0804', ' 0.280000', ' 37.977388', ' 23.737690', ' 4.6442', ' -0.6543', ' -0.0905', ' 0.320000', ' 37.977388', ' 23.737690', ' 4.5437', ' -0.7413', ' -0.1017', ' 0.360000', ' 37.977387', ' 23.737690', ' 4.4311', ' -0.8227', ' -0.1143', ' 0.400000', ' 37.977387', ' 23.737691', ' 4.3046', ' -0.9354', ' -0.1285', ' 0.440000', ' 37.977386', ' 23.737691', ' 4.1600', ' -1.0729', ' -0.1439', ' 0.480000', ' 37.97738
# ...
